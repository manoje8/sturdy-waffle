# %%
import re
import numpy as np

# %%
log = "Error on 2023-10-27: Server unavailable. User ID: 42."

# %%
date_match = re.search(r"\d{4}-\d{2}-\d{2}", log)

# %%
date_match.group()

# %%
rep = re.sub(r"e.", "+", log)

# %%
rep

# %%
numbers = re.findall(r"\d+", log)

# %%
numbers

# %%
arr = np.array([1, 2, {"a": 1}])

# %%
print(arr)
print(arr.dtype)
